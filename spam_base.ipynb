# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbr
#pd.set_option("display.max_rows", None)
#pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("/Users/tadiostilahun/visoal studio/spambase.csv")
df

# %%
df.iloc[:,39:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4601 entries, 0 to 4600
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_direct            4601 non-null   float64
#  1   word_freq_cs                4601 non-null   float64
#  2   word_freq_meeting           4601 non-null   float64
#  3   word_freq_original          4601 non-null   float64
#  4   word_freq_project           4601 non-null   float64
#  5   word_freq_re                4601 non-null   float64
#  6   word_freq_edu               4601 non-null   float64
#  7   word_freq_table             4601 non-null   float64
#  8   word_freq_conference        4601 non-null   float64
#  9   char_freq_;                 4601 non-null   float64
#  10  char_freq_(                 4601 non-null   float64
#  11  char_freq_[                 4601 non-null   float64
#  12  char_freq_!                 4601 non-null   float64
# ...

# %%
df.corr().iloc[-1,39:]
# Out:
# word_freq_direct             -0.064801
# word_freq_cs                 -0.097375
# word_freq_meeting            -0.136615
# word_freq_original           -0.135664
# word_freq_project            -0.094594
# word_freq_re                 -0.140408
# word_freq_edu                -0.146138
# word_freq_table              -0.044679
# word_freq_conference         -0.084020
# char_freq_;                  -0.059630
# char_freq_(                  -0.089672
# char_freq_[                  -0.064709
# char_freq_!                   0.241888
# char_freq_$                   0.323629
# char_freq_#                   0.065067
# capital_run_length_average    0.109999
# capital_run_length_longest    0.216097
# capital_run_length_total      0.249164
# spam                          1.000000
# Name: spam, dtype: float64

# %%
sbr.countplot(x=df['spam'])
plt.title('Distribution of Spam and Non-Spam Emails')
plt.show()

# %%
df.hist(bins=20, figsize=(20, 15))
plt.show()

# %%
from sklearn.model_selection import train_test_split
x = df.drop("spam", axis= 1)
y = df["spam"]
x_tarin, x_test, y_train, y_test = train_test_split(x, y, train_size= 0.67, random_state= 33)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_tarin, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# this model score is bad but i will come and fix it in the futer.

# %%
y_pridict = gnb.predict(x_test)
from sklearn.metrics import r2_score
r2_score(y_test, y_pridict)
# Out:
# 0.2216020719637407
